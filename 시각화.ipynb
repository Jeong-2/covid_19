# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
display(HTML("<style>.input_area pre {font-family: Consolas; font-size: 10pt; line-height: 140%;}</style>"))
display(HTML("<style>.output_area pre {font-family: Consolas; font-size: 10pt; line-height: 140%;}</style>"))


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
# Out:
# <style>.container { width:95% !important; }</style>
# <style>.input_area pre {font-family: Consolas; font-size: 10pt; line-height: 140%;}</style>
# <style>.output_area pre {font-family: Consolas; font-size: 10pt; line-height: 140%;}</style>

# %%
# 시각화, 한글깨짐 처리
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font',family=font_name)

# %%
#파일읽기
Co_p=pd.read_excel("질본사망자.xlsx",sheet_name="지역별+경로별")
Co_p.head()
Co_a=pd.read_excel("질본사망자.xlsx",sheet_name="연령별")
Co_a.head()
Co_s=pd.read_excel("질본사망자.xlsx",sheet_name="성별")
Co_s.head()

#날짜를 인덱스로 하여 정보 불러오기
Co_pD=pd.read_excel("질본사망자.xlsx",sheet_name="지역별+경로별",index_col='날짜')
Co_pD.head()
Co_aD=pd.read_excel("질본사망자.xlsx",sheet_name="연령별",index_col='날짜')
Co_aD.head()
Co_sD=pd.read_excel("질본사망자.xlsx",sheet_name="성별",index_col='날짜')
Co_sD.head()

#날짜로 그룹화하기
D_groups=Co_p.groupby(Co_p['날짜'])
D_groups.head()

Co_aA=pd.read_excel("질본사망자.xlsx",sheet_name="연령별",index_col='연령')
Co_aA.head()
# Out:
#     날짜  지역    누계  해외유입    소계 신천지관련  집단발병  확진자 접촉자  해외유입관련   기타   신규  \
# 0  302  서울    91   NaN   100     4   NaN      NaN    18.0   69    9
# 1  302  부산    88   NaN    93     9   NaN      NaN     0.0   77    7
# 2  302  대구  3081   NaN  3593  2136   NaN      NaN     0.0  943  514
# 3  302  인천     7   NaN     8     1   NaN      NaN     1.0    5    1
# 4  302  광주     9   NaN     9     7   NaN      NaN     1.0    1    0
#
#   Unnamed: 11
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#     날짜      연령  확진자 사망
# 0  302  80세 이상   81  3
# 1  302   70-79  192  6
# 2  302   60-69  530  6
# 3  302   50-59  834  5
# 4  302   40-49  633  1
#     날짜  남성확진자  여성확진자  남성사망자  여성사망사
# 0  302   1591   2621     13      9
# 1  303   1810   3002     16     12
# 2  304   1996   3332     20     12
# 3  305   2149   3617     21     14
# 4  306   2345   3939     25     17
#      지역    누계  해외유입    소계 신천지관련  집단발병  확진자 접촉자  해외유입관련   기타   신규 Unnamed: 11
# 날짜
# ...

# %%
#3월2일 데이터
Mar2=Co_pD.loc[302]
Mar2

#3월2일 지역별 신규확진자 그래프
fig=plt.figure(figsize=(15,15), dpi=100)
ax=fig.add_subplot(1,2,1)
ax.set_title('3/2 NEW region')
X=['서울','부산','대구','인천','광주','대전','울산','세종','경기','강원','충북','충남','전북','전남','경북','경남','제주']
color_list=['r','lightcoral','orange','yellow','darkseagreen','forestgreen','lightskyblue','steelblue','cornflowerblue','plum','mediumslateblue','mediumorchid','orchid','hotpink','lightpink','pink']
ax.bar(X,Mar2['신규'],color=color_list)
for p in ax.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax.annotate("%.f"%(height), xy=(left+width/2, bottom+height/2), ha='center', va='center')
plt.sca(ax) 
plt.box(False)
fig.show()
# Out:
#      지역    누계  해외유입    소계 신천지관련  집단발병  확진자 접촉자  해외유입관련   기타   신규 Unnamed: 11
# 날짜
# 302  서울    91   NaN   100     4   NaN      NaN    18.0   69    9         NaN
# 302  부산    88   NaN    93     9   NaN      NaN     0.0   77    7         NaN
# 302  대구  3081   NaN  3593  2136   NaN      NaN     0.0  943  514         NaN
# 302  인천     7   NaN     8     1   NaN      NaN     1.0    5    1         NaN
# 302  광주     9   NaN     9     7   NaN      NaN     1.0    1    0         NaN
# 302  대전    14   NaN    15     0   NaN      NaN     0.0   14    1         NaN
# 302  울산    20   NaN    23    10   NaN      NaN     0.0   10    3         NaN
# 302  세종     1   NaN     1     1   NaN      NaN     0.0    0    0         NaN
# 302  경기    92   NaN   100    16   NaN      NaN    11.0   65    8         NaN
# 302  강원    19   NaN    31     7   NaN      NaN     0.0   12   12         NaN
# 302  충북    11   NaN    11     5   NaN      NaN     0.0    6    0         NaN
# ...

# %%
#3월2일 성별 확진자
fig=plt.figure(figsize=(3,3), dpi=100)
ax1=fig.add_subplot(1,1,1)
X=['302']
ax1.set_title('3/2 NEW Gender')
Mar2_M=Co_sD['남성확진자'].loc[302]
Mar2_W=Co_sD['여성확진자'].loc[302]
_=ax1.bar(X,Mar2_M,color='b',width=0.2)
_=ax1.bar(X,Mar2_W,color='r',bottom=Mar2_M,width=0.2)
for p in ax1.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax1.annotate("%.f"%(height), xy=(left+width/2, bottom+height/2), ha='center', va='center',color='white')
plt.sca(ax1) 
plt.box(False)
fig.show()
# Out:
# Text(0.5,1,'3/2 NEW Gender')
# Text(0,795.5,'1591')
# Text(0,2901.5,'2621')
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
#3월7일 나이별 신규확진자 그래프
fig=plt.figure(figsize=(10,10), dpi=100)
ax1=fig.add_subplot(1,1,1)
Y=['upper80','70s','60s','50s','40s','30s','20s','10s','0s']
color_list=['r','orange','yellow','olivedrab','lightskyblue','royalblue','m','mediumpurple','lightpink']
ax1.bar(Y,Co_aD['확진자'].loc[307],color=color_list)
ax1.set_title('3/7 NEW Age')
for p in ax1.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax1.annotate("%.f"%(height), xy=(left+width/2, bottom+height/2), ha='center', va='center')
plt.sca(ax1) 
plt.box(False)

fig.show()
# Out:
# <Container object of 9 artists>
# Text(0.5,1,'3/7 NEW Age')
# Text(8,95.5,'191')
# Text(7,192,'384')
# Text(6,415,'830')
# Text(5,643.5,'1287')
# Text(4,470.5,'941')
# Text(3,363.5,'727')
# Text(2,1014,'2028')
# Text(1,163.5,'327')
# Text(0,26,'52')
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
#3월로 확진 경로 확진자
fig=plt.figure(figsize=(20,20), dpi=100)
ax=fig.add_subplot(1,2,1)
Mar=pd.DataFrame(Co_pD.loc[30131])
#Mar=Co_pD.loc[30131]
Mar=Mar[1:10]
Mar
color_list=['lightcoral','orange','yellow','olivedrab','lightskyblue','royalblue','m','mediumpurple','lightpink']
X=['누계','해외유입','소계','신천지','집단발병','확진자접촉','해외유입관련','기타','신규']

ax.bar(X,Mar[30131],color=color_list)

for p in ax.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax.annotate("%.f"%(height), xy=(left+width/2, bottom+height/2), ha='center', va='center')
plt.sca(ax) 
plt.box(False)

fig.show()
# Out:
#           30131
# 누계       237762
# 해외유입       1437
# 소계       241846
# 신천지관련    139014
# 집단발병      30228
# 확진자 접촉자   19547
# 해외유입관련      607
# 기타        46810
# 신규         5871
# <Container object of 9 artists>
# Text(1,118881,'237762')
# Text(6,718.5,'1437')
# Text(2,120923,'241846')
# Text(4,69507,'139014')
# Text(5,15114,'30228')
# Text(8,9773.5,'19547')
# Text(7,303.5,'607')
# Text(0,23405,'46810')
# Text(3,2935.5,'5871')
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
##for문 써서 성별 일별 확진자 나타내보기
fig=plt.figure(figsize=(10,10), dpi=100)
ax1=fig.add_subplot(1,1,1)
for ii in range(302,332):
    X=[]
    x='{}'.format(ii)
    X.append(x)
    ax1.set_title('MARCH NEW Gender')
    Mar_M=Co_sD['남성확진자'].loc[ii]
    _=ax1.bar(X,Mar_M,color='b',width=0.2)
    Mar_W=Co_sD['여성확진자'].loc[ii]
    _=ax1.bar(X,Mar_W,color='r',bottom=Mar_M,width=0.2)
    Mar_M
    Mar_W
_=ax1.legend(labels=['MAN', 'WOMAN'])
for p in ax1.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax1.annotate("%.f"%(height), xy=(left+width/2, bottom+height/2), ha='center', va='center')
plt.sca(ax1) 
plt.box(False)
fig.show()
# Out:
# Text(0.5,1,'MARCH NEW Gender')
# 1591
# 2621
# Text(0.5,1,'MARCH NEW Gender')
# 1810
# 3002
# Text(0.5,1,'MARCH NEW Gender')
# 1996
# 3332
# Text(0.5,1,'MARCH NEW Gender')
# 2149
# 3617
# Text(0.5,1,'MARCH NEW Gender')
# 2345
# 3939
# Text(0.5,1,'MARCH NEW Gender')
# 2522
# 4245
# Text(0.5,1,'MARCH NEW Gender')
# 2694
# 4440
# Text(0.5,1,'MARCH NEW Gender')
# 2799
# 4583
# Text(0.5,1,'MARCH NEW Gender')
# 2852
# 4661
# Text(0.5,1,'MARCH NEW Gender')
# 2947
# 4808
# Text(0.5,1,'MARCH NEW Gender')
# 2994
# 4875
# Text(0.5,1,'MARCH NEW Gender')
# 3043
# 4936
# Text(0.5,1,'MARCH NEW Gender')
# 3100
# 4986
# Text(0.5,1,'MARCH NEW Gender')
# 3136
# 5026
# Text(0.5,1,'MARCH NEW Gender')
# 3169
# 5067
# Text(0.5,1,'MARCH NEW Gender')
# 3200
# 5120
# Text(0.5,1,'MARCH NEW Gender')
# 3240
# 5173
# Text(0.5,1,'MARCH NEW Gender')
# 3296
# 5269
# Text(0.5,1,'MARCH NEW Gender')
# 3330
# 5322
# Text(0.5,1,'MARCH NEW Gender')
# 3387
# 5412
# Text(0.5,1,'MARCH NEW Gender')
# 3430
# 5467
# ...

# %%
#3월 남녀확진자 사망자 파이그림으로 
fig=plt.figure(figsize=(15,15), dpi=100)
i=1
for ii in range(302,332):
    ax=fig.add_subplot(10,3,i)
    Mar=[Co_sD['남성확진자'].loc[ii],Co_sD['여성확진자'].loc[ii]]
    _=ax.pie(Mar,colors=['b','r'],autopct='%0.1f%%')
    ax.set_title('0{}'.format(ii))
    i+=1
ax.legend(labels=['MAN','WOMAN'])

fig.show()
# Out:
# Text(0.5,1,'0302')
# Text(0.5,1,'0303')
# Text(0.5,1,'0304')
# Text(0.5,1,'0305')
# Text(0.5,1,'0306')
# Text(0.5,1,'0307')
# Text(0.5,1,'0308')
# Text(0.5,1,'0309')
# Text(0.5,1,'0310')
# Text(0.5,1,'0311')
# Text(0.5,1,'0312')
# Text(0.5,1,'0313')
# Text(0.5,1,'0314')
# Text(0.5,1,'0315')
# Text(0.5,1,'0316')
# Text(0.5,1,'0317')
# Text(0.5,1,'0318')
# Text(0.5,1,'0319')
# Text(0.5,1,'0320')
# Text(0.5,1,'0321')
# Text(0.5,1,'0322')
# Text(0.5,1,'0323')
# Text(0.5,1,'0324')
# Text(0.5,1,'0325')
# Text(0.5,1,'0326')
# Text(0.5,1,'0327')
# Text(0.5,1,'0328')
# Text(0.5,1,'0329')
# Text(0.5,1,'0330')
# Text(0.5,1,'0331')
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
#3월 전체 남녀확진자 확진자 파이그림으로 
fig=plt.figure(figsize=(10,10), dpi=100)
ax=fig.add_subplot(1,1,1)
A=[]
B=[]
for ii in range(302,332):
    a=Co_sD['남성확진자'].loc[ii]
    A.append(a)
    b=Co_sD['여성확진자'].loc[ii]
    B.append(b)
    A1=sum(A)
    B1=sum(B)
Mar=[A1,B1]
_=ax.pie(Mar,colors=['lightskyblue','lightpink'],autopct='%0.1f%%')
ax.set_title('March GENDER')
ax.legend(labels=['MAN','WOMAN'])


fig.show()
# Out:
# Text(0.5,1,'March GENDER')
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
#전체 남녀확진자 파이그림으로 
fig=plt.figure(figsize=(5,5), dpi=100)
ax=fig.add_subplot(1,1,1)
A=[]
B=[]
for ii in range(302,332):
    a=Co_sD['남성확진자'].loc[ii]
    A.append(a)
    b=Co_sD['여성확진자'].loc[ii]
    B.append(b)
    A1=sum(A)
    B1=sum(B)
for ii in range(401,431):
    a=Co_sD['남성확진자'].loc[ii]
    A.append(a)
    b=Co_sD['여성확진자'].loc[ii]
    B.append(b)
    A1=sum(A)
    B1=sum(B)
for ii in range(502,532):
    a=Co_sD['남성확진자'].loc[ii]
    A.append(a)
    b=Co_sD['여성확진자'].loc[ii]
    B.append(b)
    A1=sum(A)
    B1=sum(B)
for ii in range(601,631):
    a=Co_sD['남성확진자'].loc[ii]
    A.append(a)
    b=Co_sD['여성확진자'].loc[ii]
    B.append(b)
    A1=sum(A)
    B1=sum(B)
for ii in range(701,725):
    a=Co_sD['남성확진자'].loc[ii]
    A.append(a)
    b=Co_sD['여성확진자'].loc[ii]
    B.append(b)
    A1=sum(A)
    B1=sum(B)
Mar=[A1,B1]
_=ax.pie(Mar,colors=['lightskyblue','lightpink'],autopct='%0.1f%%')
ax.set_title('GENDER')
ax.legend(labels=['MAN','WOMAN'])


fig.show()
# Out:
# Text(0.5,1,'GENDER')
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
#전체의 나이대별 확진자 퍼센트 파이그림으로 
fig=plt.figure(figsize=(10,10), dpi=100)
ax=fig.add_subplot(1,1,1)
color_list=['r','orange','yellow','olivedrab','lightskyblue','royalblue','m','mediumpurple','lightpink']
A=[]
B=[]
C=[]
D=[]
E=[]
F=[]
G=[]
H=[]
I=[]
for i in range(1,146):
    a=Co_aA['확진자'].loc['80세 이상']
    A.append(a)
    b=Co_aA['확진자'].loc['70-79']
    B.append(b)
    c=Co_aA['확진자'].loc['60-69'] 
    C.append(c)
    d=Co_aA['확진자'].loc['50-59']
    D.append(d)
    e=Co_aA['확진자'].loc['40-49']
    E.append(e)
    f=Co_aA['확진자'].loc['30-39']
    F.append(f)
    g=Co_aA['확진자'].loc['20-29']
    G.append(g)
    h=Co_aA['확진자'].loc['10-19']
    H.append(h)
    i=Co_aA['확진자'].loc['0-9']
    I.append(i)
    A1=sum(sum(A))
    B1=sum(sum(B))
    C1=sum(sum(C))
    D1=sum(sum(D))
    E1=sum(sum(E))
    F1=sum(sum(F))
    G1=sum(sum(G))
    H1=sum(sum(H))
    I1=sum(sum(I))

aA=[A1,B1,C1,D1,E1,F1,G1,H1,I1]
_=ax.pie(aA,colors=color_list,autopct='%0.1f%%')
ax.set_title('AGE confirmed case')
ax.legend(labels=['upper80','70s','60s','50s','40s','30s','20s','10s','0s'])


fig.show()
# Out:
# Text(0.5,1,'AGE confirmed case')
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
#전체의 나이대별 사망자 퍼센트 파이그림으로 
fig=plt.figure(figsize=(10,10), dpi=100)
ax=fig.add_subplot(1,1,1)
color_list=['r','orange','yellow','olivedrab','lightskyblue','royalblue','m','mediumpurple','lightpink']
A=[]
B=[]
C=[]
D=[]
E=[]
F=[]
G=[]
H=[]
I=[]
for i in range(1,146):
    a=Co_aA['사망'].loc['80세 이상']
    A.append(a)
    b=Co_aA['사망'].loc['70-79']
    B.append(b)
    c=Co_aA['사망'].loc['60-69'] 
    C.append(c)
    d=Co_aA['사망'].loc['50-59']
    D.append(d)
    e=Co_aA['사망'].loc['40-49']
    E.append(e)
    f=Co_aA['사망'].loc['30-39']
    F.append(f)
    g=Co_aA['사망'].loc['20-29']
    G.append(g)
    h=Co_aA['사망'].loc['10-19']
    H.append(h)
    i=Co_aA['사망'].loc['0-9']
    I.append(i)
    A1=sum(sum(A))
    B1=sum(sum(B))
    C1=sum(sum(C))
    D1=sum(sum(D))
    E1=sum(sum(E))
    F1=sum(sum(F))
    G1=sum(sum(G))
    H1=sum(sum(H))
    I1=sum(sum(I))

aA=[A1,B1,C1,D1,E1,F1,G1,H1,I1]
_=ax.pie(aA,colors=color_list,autopct='%0.1f%%')
ax.set_title('AGE Death')
ax.legend(labels=['upper80','70s','60s','50s','40s','30s','20s','10s','0s'])


fig.show()
# Out:
# Text(0.5,1,'AGE Death')
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
#for문 3월 일별 지역별
fig=plt.figure(figsize=(15,15),dpi=100)
X=['서울','부산','대구','인천','광주','대전','울산','세종','경기','강원','충북','충남','전북','전남','경북','경남','제주']
i=1
for ii in range(302,306):
    ax=fig.add_subplot(2,2,i)
    _=ax.set_title('0{} 지역 신규'.format(ii)) 
    _=ax.bar(X,Co_pD.loc[ii]['신규'])
    i+=1
fig.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
#FOR문 3월나이별 신규확진자 그래프

fig=plt.figure(figsize=(10,10), dpi=100)
Y=['upper80','70s','60s','50s','40s','30s','20s','10s','0s']
i=1
for ii in range(302,306):
    ax=fig.add_subplot(2,2,i)
    _=ax.set_title('March {} NEW AGE'.format(ii))
    _=ax.bar(Y,Co_aD['확진자'].loc[ii])
    i+=1
    
fig.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
#월별 경로별 확진자
fig=plt.figure(figsize=(15,15), dpi=100)
ax=fig.add_subplot(3,2,1)
ax1=fig.add_subplot(3,2,2)
ax2=fig.add_subplot(3,2,3)
ax3=fig.add_subplot(3,2,4)
ax4=fig.add_subplot(3,2,5)
X=['누계','해외유입','소계','신천지','집단발병','확진자접촉','해외유입관련','기타','신규']
Mar=pd.DataFrame(Co_pD.loc[30131])
APR=pd.DataFrame(Co_pD.loc[40130])
MAY=pd.DataFrame(Co_pD.loc[50131])
JUN=pd.DataFrame(Co_pD.loc[60130])
JUL=pd.DataFrame(Co_pD.loc[70131])
Mar=Mar[1:10]
APR=APR[1:10]
MAY=MAY[1:10]
JUN=JUN[1:10]
JUL=JUL[1:10]

_=ax.bar(X,Mar[30131])
_=ax1.bar(X,APR[40130])
_=ax2.bar(X,MAY[50131])
_=ax3.bar(X,JUN[60130])
_=ax4.bar(X,JUL[70131])
for p in ax.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax.annotate("%.f"%(height), xy=(left+width/2, bottom+height/2), ha='center', va='center')
plt.sca(ax) 
plt.box(False)
_=ax.set_title('March NEW AGE')
_=ax1.set_title('APR NEW AGE')
_=ax2.set_title('MAY NEW AGE')
_=ax3.set_title('JUN NEW AGE')
_=ax4.set_title('JUL NEW AGE')

for p in ax1.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax1.annotate("%.f"%(height), xy=(left+width/2, bottom+height/2), ha='center', va='center')
plt.sca(ax1) 
plt.box(False)
for p in ax2.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax2.annotate("%.f"%(height), xy=(left+width/2, bottom+height/2), ha='center', va='center')
plt.sca(ax2) 
plt.box(False)
for p in ax3.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax3.annotate("%.f"%(height), xy=(left+width/2, bottom+height/2), ha='center', va='center')
plt.sca(ax3) 
plt.box(False)
for p in ax4.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax4.annotate("%.f"%(height), xy=(left+width/2, bottom+height/2), ha='center', va='center')
plt.sca(ax4) 
plt.box(False)


fig.show()
# Out:
# Text(1,118881,'237762')
# Text(6,718.5,'1437')
# Text(2,120923,'241846')
# Text(4,69507,'139014')
# Text(5,15114,'30228')
# Text(8,9773.5,'19547')
# Text(7,303.5,'607')
# Text(0,23405,'46810')
# Text(3,2935.5,'5871')
# Text(1,150231,'300462')
# Text(6,10980,'21960')
# Text(2,130902,'261804')
# Text(4,75484,'150968')
# Text(5,28714.5,'57429')
# Text(8,18096.5,'36193')
# Text(7,2032,'4064')
# Text(0,14950,'29900')
# Text(3,386.5,'773')
# Text(1,171115,'342230')
# Text(6,171115,'342230')
# Text(2,136406,'272812')
# Text(4,136406,'272812')
# Text(5,34486.5,'68973')
# Text(8,34486.5,'68973')
# Text(7,2459,'4918')
# Text(0,2459,'4918')
# Text(3,343,'686')
# Text(1,182229,'364458')
# Text(6,20741.5,'41483')
# Text(2,144453,'288906')
# Text(4,78194.5,'156389')
# Text(5,45180.5,'90361')
# Text(8,18682,'37364')
# Text(7,2396,'4792')
# Text(0,17034.5,'34069')
# Text(3,667,'1334')
# Text(1,161245,'322490')
# Text(6,22400.5,'44801')
# Text(2,123830,'247660')
# Text(4,62557.5,'125115')
# ...

# %%
#한글깨짐현상없앤후
X=['서울','부산','대구','인천','광주','대전','울산','세종','경기','강원','충북','충남','전북','전남','경북','경남','제주']
Y=['s','bs','dg','ic','gwj','dj','us','sj','gg','gw','cb','cn','jb','jn','gb','gn','jj']
fig=plt.figure(figsize=(15,15), dpi=100)
ax1=fig.add_subplot(2,2,1)
ax1.set_title('3/2 NEW')
_=ax1.bar(X,Co_pD['신규'].loc[302],'b')
#ax1.set_xticklabels(['서울','부산','대구','인천','광주','대전','울산','세종','경기','강원','충북','충남','전북','전남','경북','경남','제주'])
ax2=fig.add_subplot(2,2,2)
ax2.set_title('3/3 NEW')
_=ax2.bar(X,Co_pD['신규'].loc[303],'b')
ax3=fig.add_subplot(2,2,3)
ax3.set_title('3/4 NEW')
_=ax3.bar(X,Co_pD['신규'].loc[304],'b')
ax4=fig.add_subplot(2,2,4)
ax4.set_title('3/5 NEW')
_=ax4.bar(X,Co_pD['신규'].loc[305],'b')
# Out:
# Text(0.5,1,'3/2 NEW')
# Text(0.5,1,'3/3 NEW')
# Text(0.5,1,'3/4 NEW')
# Text(0.5,1,'3/5 NEW')

# %%
#3월 날짜별 남녀 신규확진자수
Co_s2=pd.read_excel("질본사망자2.xlsx",sheet_name="성별")
#Co_s.head()
data=Co_s2.iloc[:,:]
plt.figure(figsize=(20,5))
plt.plot(data.날짜,data.남성확진자,label='남성확진자',color='blue')
plt.plot(data.날짜,data.여성확진자,label='여성확진자',color='red')
plt.grid()
plt.legend()
plt.xlabel('날짜')
plt.ylabel('신규확진자수')
plt.show()
# Out:
# Text(0.5,0,'날짜')
# Text(0,0.5,'신규확진자수')

# %%
#확진자 선형그래프
Co_s2 = pd.read_excel('질본사망자2.xlsx',sheet_name='성별')
Co_s2.head()
data=Co_s2.iloc[:, :]
plt.figure(figsize=(20,5))
plt.plot(data.날짜,data.여성확진자누적,label='여성확진자누적',color='red')
plt.plot(data.날짜,data.남성확진자누적,label='남성확진자누적',color='blue')
plt.grid()
plt.legend()
plt.show()
# Out:
#           날짜  남성확진자  여성확진자  남성사망자  여성사망자  남성확진자누적  여성확진자누적  남성사망자누적  여성사망자누적
# 0 2020-03-02    219    381     13      9     1591     2621       13        9
# 1 2020-03-03    186    330     16     12     1810     3002       16       12
# 2 2020-03-04    153    285     20     12     1996     3332       20       12
# 3 2020-03-05    196    322     21     14     2149     3617       21       14
# 4 2020-03-06    177    306     25     17     2345     3939       25       17

# %%
#4월15일이후 날짜별 신규 사망자
Co_s2= pd.read_excel('질본사망자2.xlsx',sheet_name='성별')
Co_s2.head()
data=Co_s2.iloc[45:, :]
plt.figure(figsize=(20,5))
plt.plot(data.날짜,data.여성사망자,label='woman')
plt.plot(data.날짜,data.남성사망자,label='man')
plt.grid()
plt.legend()

plt.show()
# Out:
#           날짜  남성확진자  여성확진자  남성사망자  여성사망자  남성확진자누적  여성확진자누적  남성사망자누적  여성사망자누적
# 0 2020-03-02    219    381     13      9     1591     2621       13        9
# 1 2020-03-03    186    330     16     12     1810     3002       16       12
# 2 2020-03-04    153    285     20     12     1996     3332       20       12
# 3 2020-03-05    196    322     21     14     2149     3617       21       14
# 4 2020-03-06    177    306     25     17     2345     3939       25       17
