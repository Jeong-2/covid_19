# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

serviceKey="o1JKN4eRA37ogjtZamxJyyZp4vmWUj8iXiyFIDZ%2F1Vyr%2BPo34iIV7t3npKjnFE7a4aFuz2Hgu4fyHIlcwhz0iQ%3D%3D"

def searchByYM(startCreateDt,endCreateDt): 
    numOfRows = '400' 
    pageNo = '4'
    
    url = 'http://openapi.data.go.kr/openapi/service/rest/Covid19/getCovid19GenAgeCaseInfJson?serviceKey=o1JKN4eRA37ogjtZamxJyyZp4vmWUj8iXiyFIDZ%2F1Vyr%2BPo34iIV7t3npKjnFE7a4aFuz2Hgu4fyHIlcwhz0iQ%3D%3D&pageNo=1&numOfRows=10&startCreateDt=20200310&endCreateDt=20200414'
    res = requests.get(url)
    
    soup = BeautifulSoup(res.text,'lxml-xml')
    it = soup.select('item')
    
    rows = []
    for node in it:
        n_confcase = node.find('confCase').text
        n_confcaserate = node.find('confCaseRate').text
        n_createdt = node.find('createDt').text
        n_criticalrate = node.find('criticalRate').text
        n_death = node.find('death').text
        n_deathrate = node.find('deathRate').text 
        n_gubun = node.find('gubun').text
        n_seq = node.find('seq').text
        rows.append({"확진자":n_confcase,
                     "확진률":n_confcaserate,
                     "등록일시분초":n_createdt,
                     "치명률":n_criticalrate,
                     "사망자":n_death,
                     "사망률":n_deathrate,
                     "구분":n_gubun,
                     "게시글번호":n_seq,
                     })
        
    columns = ["확진자","확진률","등록일시분초","치명률","사망자","사망률","구분","게시글번호" ]
    df = pd.DataFrame(rows, columns= columns)
    return df

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
area1 = searchByYM('20200310','20200414')
print(area1)
# Out:
#       확진자    확진률                  등록일시분초    치명률  사망자    사망률     구분 게시글번호
# 0     132   1.25  2020-04-14 10:24:23.23      0    0   0.00    0-9   145
# 1     565   5.35  2020-04-14 10:24:23.23      0    0   0.00  10-19   144
# 2    2886  27.32  2020-04-14 10:24:23.23      0    0   0.00  20-29   143
# 3    1126  10.66  2020-04-14 10:24:23.23   0.09    1   0.45  30-39   142
# 4    1405   13.3  2020-04-14 10:24:23.23   0.21    3   1.35  40-49   141
# 5    1935  18.32  2020-04-14 10:24:23.23   0.72   14   6.31  50-59   140
# 6    1338  12.67  2020-04-14 10:24:23.23   2.47   33  14.86  60-69   139
# 7     700   6.63  2020-04-14 10:24:23.23   9.29   65  29.28  70-79   138
# 8     477   4.52  2020-04-14 10:24:23.23  22.22  106  47.75  80 이상   137
# 9    6308  59.71  2020-04-14 10:24:23.23   1.68  106  47.75     여성   136
# 10   4256  40.29  2020-04-14 10:24:23.23   2.73  116  52.25     남성   135
# 11    132   1.25  2020-04-13 10:22:30.30      0    0   0.00    0-9   134
# ...
